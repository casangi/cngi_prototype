# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/cngi_prototype/blob/master/docs/imaging/cube_imaging_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cube Imaging
# This notebook will demonstrate how to create a cube dirty image with natural weighting using ngCASA. The resulting image will be compared with an image created by CASA. The Dask visualize tool will also be introduced.
#
# For this demonstration data from the ALMA First Look at Imaging CASAguide (https://casaguides.nrao.edu/index.php/First_Look_at_Imaging) will be used. The measurement set has been converted to vis.zarr (using convert_ms in cngi.conversion).
#
# This walkthrough is designed to be run in a Jupyter notebook on Google Colaboratory. To open the notebook in colab, go [here](https://colab.research.google.com/github/casangi/cngi_prototype/blob/master/docs/imaging/cube_imaging_example.ipynb).

# %% [markdown]
# ## Installation and Dataset Download

# %%
import os

#os.system("pip install --extra-index-url https://test.pypi.org/simple/ cngi-prototype==0.0.84")

# !gdown -q --id 1fN3rdEQoeKExyIVBP87ZHdJTNuugkTJ0
# !unzip sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr.zip

# !gdown -q --id 1KpMk_BpRVsomnvPRYYAoaVByEhhgg2mU
# !unzip casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr.zip

# %matplotlib widget
print('complete')
# Out:
# Archive:  sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr.zip
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.5.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.1.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.6.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.2.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.3.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.4.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/6
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/1
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/4
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/3
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/2
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/5
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/6
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/1
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/4
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/3
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/2
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/5
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.5.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.1.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.6.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.2.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.3.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.4.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/time/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/time/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/time/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/time/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/6
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/1
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/4
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/3
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/2
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/5
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.5.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.1.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.6.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.2.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.3.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.4.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.0.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/xds0/.zmetadata
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/.version
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/0.0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zgroup
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/0.0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/0.0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/source_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/source_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/source_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/source_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NAME/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASEDIR_REF/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASEDIR_REF/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASEDIR_REF/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASEDIR_REF/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASE_DIR/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASE_DIR/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASE_DIR/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/PHASE_DIR/0.0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/DISHDIAMETER/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/DISHDIAMETER/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/DISHDIAMETER/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/DISHDIAMETER/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/POSITION/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/POSITION/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/POSITION/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/POSITION/0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAID/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/STATIONID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/STATIONID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/STATIONID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/STATIONID/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/TIME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/TIME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/TIME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/TIME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/OFFSET/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/OFFSET/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/OFFSET/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/OFFSET/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ASSOCANTENNAID/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ASSOCANTENNAID/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ASSOCANTENNAID/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ASSOCANTENNAID/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAMAKE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAMAKE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAMAKE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNAMAKE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/NAME/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/NAME/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/NAME/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/.zmetadata
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNATYPE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNATYPE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNATYPE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_ANTENNA/ANTENNATYPE/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_RECEPTOR/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_RECEPTOR/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_RECEPTOR/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_RECEPTOR/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_CAL_LOAD/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_CAL_LOAD/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_CAL_LOAD/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/NUM_CAL_LOAD/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/feed_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/feed_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/feed_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/feed_id/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/INTERVAL/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/INTERVAL/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/INTERVAL/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/CALDEVICE/INTERVAL/0
# ...
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/.zattrs
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/0.0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zattrs
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/0
#  extracting: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zgroup
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/0.0
#    creating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/.zarray
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/.zattrs
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/0
#   inflating: sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zmetadata
# Archive:  casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr.zip
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/pol/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/pol/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/pol/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/pol/0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/chan/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/chan/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/chan/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/chan/0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PB_MASK0/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.5.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/SUMWT/0.6.0
#  extracting: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/.zgroup
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL_MASK0/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/time/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/time/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/time/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/time/0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/declination/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/declination/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/declination/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/declination/0.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_MASK0/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/MODEL/0.0.0.5.0
#  extracting: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/.version
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/PSF/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/m/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/m/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/m/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/m/0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/.zmetadata
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.4.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.3.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.2.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.6.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.1.0
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/RESIDUAL/0.0.0.5.0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/l/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/l/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/l/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/l/0
#    creating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/right_ascension/
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/right_ascension/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/right_ascension/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr/right_ascension/0.0
# complete

# %% [markdown]
# ## Load Dataset
#
# Two datasets are are needed for this notebook:
# - sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr
# - casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr
#
# (for more information about the img.zarr format go [here](https://cngi-prototype.readthedocs.io/en/latest/visibilities.html) and for the vis.zarr format go [here](https://cngi-prototype.readthedocs.io/en/latest/images.html)).
#
# The sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr dataset is used to create a cube image. The dataset was created by using the ```mstransform``` command in CASA
#
# ```python
# mstransform('sis14_twhya_calibrated_flagged.ms',
#             outputvis='sis14_twhya_chan_avg_field_5_lsrk_pol_xx.ms',
#             regridms=True, outframe='LSRK', datacolumn='data',
#             correlation='XX', field='5', nchan=7)
# ```
#
# and then convert_ms in cngi.conversion
#
# ```python
# infile = 'sis14_twhya_chan_avg_field_5_lsrk_pol_xx.ms'
# outfile = 'sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr'
# chunk_shape=(270, 210, 1, 1)
# convert_ms(infile, outfile=outfile, chunk_shape=chunk_shape)
# ```
#
# The conversion to 'LSRK' is necessary because cngi does not currently have an implementation and tclean does a conversion to 'LSRK' before imaging.
#
# To check the ngcasa imaging results the casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr dataset is used. This dataset was generated by running ```tclean``` in CASA
#
# ```python
# tclean(vis='sis14_twhya_chan_avg_field_5_lsrk_pol_xx.ms',
#        imagename='twhya_standard_gridder_lsrk_cube_natural',
#        specmode='cube',
#        deconvolver='hogbom',
#        imsize=[200,400],
#        cell=['0.08arcsec'],
#        weighting='natural',
#        threshold='0mJy',
#        niter=0,stokes='XX')
# ```
#
# and then ```image_ms``` in cngi.conversion
#
# ```python
# infile = 'cube_image/twhya_standard_gridder_lsrk_cube_natural.image'
# outfile = 'casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr'
# convert_image(infile=infile,outfile=outfile)
# ```

# %%
import xarray as xr
from cngi.dio import read_vis, read_image

xr.set_options(display_style="html")

mxds = read_vis("sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr")
mxds.xds0
# Out:
# <xarray.Dataset>
# Dimensions:         (baseline: 210, chan: 7, pol: 1, pol_id: 1, spw_id: 1, time: 270, uvw_index: 3)
# Coordinates:
#   * baseline        (baseline) int64 0 1 2 3 4 5 6 ... 204 205 206 207 208 209
#   * chan            (chan) float64 3.725e+11 3.725e+11 ... 3.725e+11 3.725e+11
#     chan_width      (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     effective_bw    (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#   * pol             (pol) int32 9
#   * pol_id          (pol_id) int32 0
#     resolution      (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#   * spw_id          (spw_id) int32 0
#   * time            (time) datetime64[ns] 2012-11-19T07:56:26.544000626 ... 2...
# Dimensions without coordinates: uvw_index
# Data variables:
#     ANTENNA1        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ANTENNA2        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ARRAY_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     DATA            (time, baseline, chan, pol) complex128 dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     DATA_WEIGHT     (time, baseline, chan, pol) float64 dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     EXPOSURE        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED1           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED2           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FIELD_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FLAG            (time, baseline, chan, pol) bool dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     INTERVAL        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     OBSERVATION_ID  (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     PROCESSOR_ID    (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     SCAN_NUMBER     (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     STATE_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     TIME_CENTROID   (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     UVW             (time, baseline, uvw_index) float64 dask.array<chunksize=(270, 210, 3), meta=np.ndarray>
# Attributes:
#     bbc_no:           2
#     corr_product:     [[0, 0]]
#     data_groups:      [{'0': {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw...
#     freq_group:       0
#     freq_group_name:
#     if_conv_chain:    0
#     meas_freq_ref:    1
#     name:             ALMA_RB_07#BB_2#SW-01#FULL_RES
#     net_sideband:     2
#     num_chan:         7
#     num_corr:         1
#     ref_frequency:    372520022603.63745
#     total_bandwidth:  4272311.112915039

# %%
casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr")
casa_img_xds
# Out:
# <xarray.Dataset>
# Dimensions:            (chan: 7, l: 200, m: 400, pol: 1, time: 1)
# Coordinates:
#   * chan               (chan) float64 3.725e+11 3.725e+11 ... 3.725e+11
#     declination        (l, m) float64 dask.array<chunksize=(200, 400), meta=np.ndarray>
#   * l                  (l) float64 3.879e-05 3.84e-05 ... -3.801e-05 -3.84e-05
#   * m                  (m) float64 -7.757e-05 -7.718e-05 ... 7.679e-05 7.718e-05
#   * pol                (pol) float64 9.0
#     right_ascension    (l, m) float64 dask.array<chunksize=(200, 400), meta=np.ndarray>
#   * time               (time) datetime64[ns] 2012-11-19T07:56:26.544000626
# Data variables:
#     IMAGE              (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_MASK0        (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_PBCOR        (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_PBCOR_MASK0  (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     MODEL              (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PB                 (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PB_MASK0           (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PSF                (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     RESIDUAL           (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     RESIDUAL_MASK0     (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     SUMWT              (time, chan, pol) float64 dask.array<chunksize=(1, 1, 1), meta=np.ndarray>
# Attributes:
#     axisnames:            ['Right Ascension', 'Declination', 'Time', 'Frequen...
#     axisunits:            ['rad', 'rad', 'datetime64[ns]', 'Hz', '']
#     commonbeam:           [0.6639984846115112, 0.5052574276924133, -65.900550...
#     commonbeam_units:     ['arcsec', 'arcsec', 'deg']
#     date_observation:     2012/11/19/07
#     direction_reference:  j2000
#     imagetype:            Intensity
#     incr:                 [-3.878509448876288e-07, 3.878509448876288e-07, 1.0...
#     object_name:          tw hya
#     observer:             cqi
#     perplanebeams:        [[[0.6639984846115112, 0.5052574276924133, -65.9005...
#     pointing_center:      11
#     rest_frequency:       3.72522e+11 hz
#     restoringbeam:        [0.6639984846115112, 0.5052574276924133, -65.900550...
#     spectral__reference:  lsrk
#     telescope:            alma
#     telescope_position:   [2.22514e+06m, -5.44031e+06m, -2.48103e+06m] (itrf)
#     unit:                 Jy/beam
#     velocity__type:       radio

# %% [markdown]
# Note that the chunks parameter in cngi and ngcasa functions specifies the size of a chunk and not the number of chunks (in CASA ```tclean``` chanchunks refers to the number of channel chunks).
#
# The dimensionality of the sis14_twhya_chan_avg_field_5_lsrk_pol_xx.vis.zarr dataset is (time:270,baseline:210,chan:7,pol:1) and a zarr chunk size of (time:270,baseline:210,chan:1,pol:1) was chosen. The dask chunk size was chosen to be the same as the zarr chunk size. For more information concerning chunking go to [here](https://cngi-prototype.readthedocs.io/en/latest/development.html).

# %% [markdown]
# ## Flag Data and Create Imaging Weights
#
# The ```apply_flags``` cngi.vis function sets all values that should be flagged to nan. The ngcasa.imaging code does not internally apply flags but does ignore nan values. [apply_flags documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/cngi/vis/apply_flags/index.html#cngi.vis.apply_flags.apply_flags)
#
# The ```make_imaging_weight``` cngi.imaging function takes the WEIGHT or WEIGHT_SPECTRUM data variables and creates IMAGING_WEIGHT data variable that has dimensions time x baseline x chan x pol (matches the visibility DATA variable). Weighting schemes that are supported include natural, uniform, briggs, briggs_abs. Using imaging_weights_parms['chan_mode'] = 'cube' is equivalent to perchanweightdensity=True in CASA. [make_imaging_weight documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_imaging_weight/index.html#ngcasa.imaging.make_imaging_weight.make_imaging_weight)

# %%
from cngi.vis import apply_flags
from ngcasa.imaging import make_imaging_weight

mxds = apply_flags(mxds, 'xds0', flags='FLAG')

grid_parms = {}
grid_parms['chan_mode'] = 'cube'
grid_parms['image_size'] = [200,400]
grid_parms['cell_size'] = [0.08,0.08]

sel_parms = {}
sel_parms['xds'] = 'xds0'
sel_parms['data_group_in_id'] = 0

imaging_weights_parms = {}
imaging_weights_parms['weighting'] = 'natural'

mxds =  make_imaging_weight(mxds, imaging_weights_parms, grid_parms, sel_parms)

mxds.xds0
# Out:
# ######################### Start make_imaging_weights #########################
# Setting data_group_in  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT'}
# Setting default data_group_out  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'IMAGING_WEIGHT'}
# Since weighting is natural input weight will be reused as imaging weight.
# ######################### Created graph for make_imaging_weight #########################
# <xarray.Dataset>
# Dimensions:         (baseline: 210, chan: 7, pol: 1, pol_id: 1, spw_id: 1, time: 270, uvw_index: 3)
# Coordinates:
#   * baseline        (baseline) int64 0 1 2 3 4 5 6 ... 204 205 206 207 208 209
#   * chan            (chan) float64 3.725e+11 3.725e+11 ... 3.725e+11 3.725e+11
#     chan_width      (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     effective_bw    (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#   * pol             (pol) int32 9
#   * pol_id          (pol_id) int32 0
#     resolution      (chan) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#   * spw_id          (spw_id) int32 0
#   * time            (time) datetime64[ns] 2012-11-19T07:56:26.544000626 ... 2...
# Dimensions without coordinates: uvw_index
# Data variables:
#     ANTENNA1        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ANTENNA2        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ARRAY_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     DATA            (time, baseline, chan, pol) complex128 dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     DATA_WEIGHT     (time, baseline, chan, pol) float64 dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     EXPOSURE        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED1           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED2           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FIELD_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FLAG            (time, baseline, chan, pol) bool dask.array<chunksize=(270, 210, 1, 1), meta=np.ndarray>
#     INTERVAL        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     OBSERVATION_ID  (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     PROCESSOR_ID    (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     SCAN_NUMBER     (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     STATE_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     TIME_CENTROID   (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     UVW             (time, baseline, uvw_index) float64 dask.array<chunksize=(270, 210, 3), meta=np.ndarray>
# Attributes:
#     bbc_no:           2
#     corr_product:     [[0, 0]]
#     data_groups:      [{'0': {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw...
#     freq_group:       0
#     freq_group_name:
#     if_conv_chain:    0
#     meas_freq_ref:    1
#     name:             ALMA_RB_07#BB_2#SW-01#FULL_RES
#     net_sideband:     2
#     num_chan:         7
#     num_corr:         1
#     ref_frequency:    372520022603.63745
#     total_bandwidth:  4272311.112915039

# %% [markdown]
# ## Create Dirty Cube Image
# The ```make_image``` cngi.imaging function grids the data (using the prolate spheroidal function as an anti-aliasing filter), fast Fourier transform the gridded data to an image and normalizes the image. The ```make_pb``` function currently supports rotationally symmetric airy disk primary beams.
#
# [make_pb documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_mosaic_pb/index.html#ngcasa.imaging.make_mosaic_pb.make_mosaic_pb)
#
# [make_image documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_image/index.html#ngcasa.imaging.make_image.make_imagel)
#
# To create an image of the execution graph the [dask.visualize]

# %%
from ngcasa.imaging import make_image
from ngcasa.imaging import make_pb
from cngi.dio import write_image
import dask

grid_parms = {}
grid_parms['chan_mode'] = 'cube'
grid_parms['image_size'] = [200,400]
grid_parms['cell_size'] = [0.08,0.08]
grid_parms['phase_center'] = mxds.FIELD.PHASE_DIR[0,0,:].data.compute()

vis_sel_parms = {}
vis_sel_parms['xds'] = 'xds0'
vis_sel_parms['data_group_in_id'] = 0

img_sel_parms = {}
img_sel_parms['data_group_out_id'] = 0

img_xds = xr.Dataset() #empty dataset

img_xds = make_image(mxds, img_xds, grid_parms, vis_sel_parms, img_sel_parms)


make_pb_parms = {}
make_pb_parms['function'] = 'alma_airy'
make_pb_parms['list_dish_diameters'] = [10.7]
make_pb_parms['list_blockage_diameters'] = [0.75]

sel_parms = {}
sel_parms['img_description_in_indx'] = 0


img_xds = make_pb(img_xds,make_pb_parms, grid_parms, sel_parms)
dask.visualize(img_xds,filename='cube_image_graph.png')
# Out:
# ######################### Start make_image #########################
# Setting default image_center  to  [100 200]
# Setting default fft_padding  to  1.2
# Setting data_group_in  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'DATA_WEIGHT'}
# Setting default data_group_out  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '1', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'DATA_WEIGHT'}
# Setting default data_group_in  to  {'id': '0'}
# Setting default data_group_out [' sum_weight ']  to  SUM_WEIGHT
# Setting default data_group_out [' image ']  to  IMAGE
# ######################### Created graph for make_image #########################
# ######################### Start make_pb #########################
# Setting default data_group_in  to  {'id': '0', 'sum_weight': 'SUM_WEIGHT', 'image': 'IMAGE'}
# Setting default data_group_out  to  {'id': '0', 'sum_weight': 'SUM_WEIGHT', 'image': 'IMAGE', 'pb': 'PB'}
# Setting default image_center  to  [100 200]
# Setting default fft_padding  to  1.2
# ######################### Created graph for make_pb #########################

# %% [markdown]
# ## Dask Visualization
#
# The Dask execution graph below shows how the images for each channel are computed in parallel. Each image is written to disk independently and Dask along with Zarr handles the virtual concatenation (the resulting img.zarr is chunked by channel). This allows for processing cubes that are larger than memory.
#
# ![title1](https://raw.githubusercontent.com/casangi/cngi_prototype/master/docs/imaging/cube_image_graph.png)

# %% [markdown]
# ## Save Image to Disk (execute graph)

# %%
img_xds = write_image(img_xds, outfile='twhya_standard_gridder_lsrk_cube_natural.img.zarr', graph_name='make_imaging_weights, make_image and make_pb')
# Out:
# Time to store and execute graph  make_imaging_weights, make_image and make_pb 0.525346040725708

# %% [markdown]
# ## Plot and Compare With CASA

# %%
import matplotlib.pylab as plt
import numpy as np
from ipywidgets import interactive
import xarray as xr


def comparison_plots_1(chan):
    img_xds = xr.open_zarr('twhya_standard_gridder_lsrk_cube_natural.img.zarr').isel(time=0,pol=0)
    casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr").isel(time=0,pol=0)
    plt.close('all')
    print('Frequency',img_xds.chan[chan].values, 'Hz')
    #print(img_xds['IMAGE'])
    dirty_image = img_xds['IMAGE'].isel(chan=chan)
    casa_dirty_image = casa_img_xds['RESIDUAL'].isel(chan=chan)
    
    minmin = np.min([np.min(casa_dirty_image.data), np.min(dirty_image.data)])
    maxmax = np.max([np.max(casa_dirty_image.data), np.max(dirty_image.data)])
    extent = extent=(np.min(casa_dirty_image.m),np.max(casa_dirty_image.m),np.min(casa_dirty_image.l),np.max(casa_dirty_image.l))

    fig0, ax0 = plt.subplots(1, 2, sharey=True, figsize=(10, 5))
    im0 = ax0[0].imshow(casa_dirty_image,vmin=minmin,vmax=maxmax,extent=extent)
    im1 = ax0[1].imshow(dirty_image,vmin=minmin, vmax=maxmax,extent=extent)
    ax0[0].title.set_text('CASA Dirty Image')
    ax0[1].title.set_text('CNGI Dirty Image')
    ax0[0].set_xlabel('m'), ax0[1].set_xlabel('m'), ax0[0].set_ylabel('l'),ax0[1].set_ylabel('l')
    fig0.colorbar(im0, ax=ax0[0], fraction=0.046, pad=0.04)
    fig0.colorbar(im1, ax=ax0[1], fraction=0.046, pad=0.04)
    plt.show()

    plt.figure()
    plt.imshow(casa_dirty_image - dirty_image,extent=extent)
    plt.title('Difference Dirty Image')
    plt.xlabel('m')
    plt.ylabel('l')
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.show()

    dirty_image = dirty_image / np.max(np.abs(dirty_image))
    casa_dirty_image = casa_dirty_image / np.max(np.abs(casa_dirty_image))

    # Calculate max error
    max_error_dirty_image = np.max(np.abs(dirty_image - casa_dirty_image)).values
    print('Max Error',max_error_dirty_image)
    # Calculate root mean square error
    rms_error_dirty_image = np.linalg.norm(dirty_image - casa_dirty_image, 'fro')
    print('RMS Error',rms_error_dirty_image)
    


interactive_plot_1 = interactive(comparison_plots_1, chan=(0, 6))
output_1 = interactive_plot_1.children[-1]
output_1.layout.auto_scroll_threshold = 9999;
interactive_plot_1


#comparison_plots_1(3)
# Out:
# interactive(children=(IntSlider(value=3, description='chan', max=6), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# The first channel (channel 0) is flagged by both ngCASA and CASA. Why CASA is flagging the last channel and ngCASA is not, this needs further investigation. Checking sis14_twhya_chan_avg_field_5_lsrk_pol_xx.ms with browsetable in CASA shows that only the first channel is flagged.
#
# The reason for the small difference between ngCASA and CASA, in channels 1 to 5, is due to ngCASA using a different implementation of the Fast Fourier Transform.

# %%
import matplotlib.pylab as plt
import numpy as np
from ipywidgets import interactive


#### Primary Beam Corrected Images ####
def comparison_plots_2(chan):
    img_xds = xr.open_zarr('twhya_standard_gridder_lsrk_cube_natural.img.zarr').isel(time=0,pol=0, dish_type=0)
    casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_cube_natural.img.zarr").isel(time=0, pol=0)
    extent = extent=(np.min(casa_img_xds.m),np.max(casa_img_xds.m),np.min(casa_img_xds.l),np.max(casa_img_xds.l))
    
    plt.close('all')
    print('Frequency',img_xds.chan[chan].values, 'Hz')
    pb_limit = 0.2
    primary_beam = img_xds.PB.isel(l=100,chan=chan).where(img_xds.PB.isel(l=100,chan=chan) > pb_limit,other=0.0)
    dirty_image_pb_cor = img_xds.IMAGE.isel(chan=chan)/img_xds.PB.isel(chan=chan)
    dirty_image_pb_cor = dirty_image_pb_cor.where(img_xds.PB.isel(chan=chan) > pb_limit,other=np.nan)

    casa_primary_beam = casa_img_xds['PB'].isel(l=100,chan=chan) #Primary beam created by CASA
    casa_dirty_image_pb_cor = (casa_img_xds['IMAGE_PBCOR'].isel(chan=chan)).where(casa_img_xds['PB'].isel(chan=chan) > pb_limit,other=np.nan) #Image created by CASA


    #Plot Primary Beams
    fig0, ax0, = plt.subplots(1, 2, sharey=True,figsize=(10, 5))
    im0 = ax0[0].plot(casa_img_xds.m,casa_primary_beam)
    im1 = ax0[1].plot(casa_img_xds.m,primary_beam)
    ax0[0].title.set_text('CASA Primary Beam Cross Section')
    ax0[1].title.set_text('ngCASA Primary Beam Cross Section')
    ax0[0].set_xlabel('m'), ax0[1].set_xlabel('m')
    ax0[0].set_ylabel('Amplitude'), ax0[1].set_ylabel('Amplitude')
    plt.show()

    plt.figure()
    plt.plot(casa_img_xds.m,casa_primary_beam-primary_beam)
    plt.title('Difference Primary Beam')
    plt.xlabel('m')
    plt.ylabel('Amplitude')
    plt.show()

    #Plotting Images
    fig0, ax0 = plt.subplots(1, 2, sharey=True,figsize=(10, 5))
    im0 = ax0[0].imshow(casa_dirty_image_pb_cor,extent=extent)
    im1 = ax0[1].imshow(dirty_image_pb_cor,extent=extent)
    ax0[0].title.set_text('CASA PB Corrected Dirty Image')
    ax0[1].title.set_text('ngCASA PB Corrected Dirty Image')
    ax0[0].set_xlabel('m'), ax0[1].set_xlabel('m'), ax0[0].set_ylabel('l'), ax0[1].set_ylabel('l')
    fig0.colorbar(im0, ax=ax0[0], fraction=0.046, pad=0.04)
    fig0.colorbar(im1, ax=ax0[1], fraction=0.046, pad=0.04)
    plt.show()

    plt.figure()
    plt.imshow(casa_dirty_image_pb_cor - dirty_image_pb_cor,extent=extent)
    plt.title('Difference Dirty Image')
    plt.xlabel('m'), plt.ylabel('l')
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.show()

    dirty_image_pb_cor = dirty_image_pb_cor / np.nanmax(np.abs(dirty_image_pb_cor))
    casa_dirty_image_pb_cor = casa_dirty_image_pb_cor / np.nanmax(np.abs(casa_dirty_image_pb_cor))
    norm_diff_image_pb_cor = dirty_image_pb_cor - casa_dirty_image_pb_cor

    # Calculate max error
    max_error_dirty_image = np.nanmax(np.abs(norm_diff_image_pb_cor))
    print('Max Normalized Error',max_error_dirty_image)
    # Calculate root mean square error
    rms_error_dirty_image = np.sqrt(np.nansum(np.square(norm_diff_image_pb_cor)))
    print('RMS Normalized Error',rms_error_dirty_image)


interactive_plot_2 = interactive(comparison_plots_2, chan=(0, 6))
output_2 = interactive_plot_2.children[-1]
output_2.layout.auto_scroll_threshold = 9999;
interactive_plot_2
#comparison_plots(3)
# Out:
# interactive(children=(IntSlider(value=3, description='chan', max=6), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# The frequency does not change enough for the primary beam to vary significantly.
#
# The difference in primary beam is due to CASA using a sampled 1D function while ngCASA calculates the PB for each pixel. If it is found that PB creation becomes a bottleneck for ngCASA the implementation will be changed to match CASA.
