# %% [markdown]
# <a href="https://colab.research.google.com/github/casangi/cngi_prototype/blob/master/docs/imaging/continuum_imaging_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Continuum Imaging
#
# This notebook will demonstrate how to create a continuum dirty image with natural weighting using ngCASA. The resulting image will be compared with an image created by CASA.
#
# For this demonstration data from the ALMA First Look at Imaging CASAguide (https://casaguides.nrao.edu/index.php/First_Look_at_Imaging) will be used. The measurement set has been converted to vis.zarr (using convert_ms in cngi.conversion)
#
# This walkthrough is designed to be run in a Jupyter notebook on Google Colaboratory. To open the notebook in colab, go [here](https://colab.research.google.com/github/casangi/cngi_prototype/blob/master/docs/imaging/continuum_imaging_example.ipynb).

# %% [markdown]
# ## Installation and Dataset Download

# %%
import os
os.system("pip install --extra-index-url https://test.pypi.org/simple/ cngi-prototype==0.0.84")

# !gdown -q --id 1PNL0ANqnN7eyYOpQ_vMslQlorUhtrUmE
# !unzip sis14_twhya_field_5_lsrk_pol_xx.vis.zarr.zip

# !gdown -q --id 19VlXp9Qyx60ld0rBSAYMVFTq5Y1KuxO8
# !unzip casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr.zip

# %matplotlib widget
print('complete')
# Out:
# Archive:  sis14_twhya_field_5_lsrk_pol_xx.vis.zarr.zip
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/UVW/0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/PROCESSOR_ID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED2/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.29.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.23.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.27.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.5.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.12.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.18.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.16.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.1.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.20.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.24.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.11.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.6.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.2.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.30.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.8.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.15.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.21.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.25.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.10.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.7.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.9.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.31.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.3.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.14.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.22.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.28.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.26.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.4.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.19.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.13.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.17.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FLAG/0.0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA2/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/EXPOSURE/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/20
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/18
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/27
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/9
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/11
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/7
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/29
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/16
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/6
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/28
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/17
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/1
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/10
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/19
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/26
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/8
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/21
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/31
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/30
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/24
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/23
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/4
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/15
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/3
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/12
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/2
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/13
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/5
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/14
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/22
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/effective_bw/25
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/spw_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/INTERVAL/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/20
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/18
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/27
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/9
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/11
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/7
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/29
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/16
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/6
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/28
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/17
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/1
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/10
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/19
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/26
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/8
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/21
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/31
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/30
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/24
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/23
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/4
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/15
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/3
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/12
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/2
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/13
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/5
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/14
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/22
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/chan_width/25
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FIELD_ID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/baseline/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/SCAN_NUMBER/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.29.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.23.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.27.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.5.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.12.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.18.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.16.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.1.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.20.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.24.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.11.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.6.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.2.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.30.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.8.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.15.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.21.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.25.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.10.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.7.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.9.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.31.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.3.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.14.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.22.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.28.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.26.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.4.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.19.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.13.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.17.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA_WEIGHT/0.0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/OBSERVATION_ID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/time/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/time/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/time/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/time/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/FEED1/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ANTENNA1/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/STATE_ID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/20
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/18
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/27
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/9
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/11
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/7
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/29
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/16
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/6
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/28
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/17
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/1
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/10
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/19
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/26
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/8
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/21
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/31
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/30
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/24
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/23
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/4
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/15
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/3
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/12
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/2
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/13
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/5
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/14
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/22
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/resolution/25
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/pol_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/TIME_CENTROID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/ARRAY_ID/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.29.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.23.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.27.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.5.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.12.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.18.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.16.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.1.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.20.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.24.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.11.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.6.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.2.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.30.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.8.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.15.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.21.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.25.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.10.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.7.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.9.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.31.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.3.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.14.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.22.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.28.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.26.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.4.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.19.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.13.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.17.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/DATA/0.0.0.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/xds0/.zmetadata
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/.version
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/assoc_spw_id/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/EFFECTIVE_BW/0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_FREQ/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/CHAN_WIDTH/0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/FREQ_GROUP_NAME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/TOTAL_BANDWIDTH/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/IF_CONV_CHAIN/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/BBC_NO/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/RESOLUTION/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/MEAS_FREQ_REF/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NUM_CHAN/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/REF_FREQUENCY/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/spectral_window_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NAME/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SPECTRAL_WINDOW/NET_SIDEBAND/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMINPUTANTENNAS/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANFREQ/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CHANWIDTH/0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALREDUCTIONID/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WATER/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/POLYFREQLIMITS/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMPOLY/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/DRYPATH/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WVRMETHOD/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/INPUTANTENNANAMES/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/NUMCHAN/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/REFTEMP/0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/STARTVALIDTIME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/WETPATH/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ANTENNANAME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/ENDVALIDTIME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/CALDATAID/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_CALWVR/PATHCOEFF/0.0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_PRODUCT/0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/CORR_TYPE/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/NUM_CORR/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zgroup
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/POLARIZATION/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/SUB_TYPE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/type_id/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/TYPE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/mode_id/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/PROCESSOR/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/PROPER_MOTION/0.0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/INTERVAL/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NUM_LINES/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CODE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/TIME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/source_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/spectral_window_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/DIRECTION/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/NAME/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/SOURCE/CALIBRATION_GROUP/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/REF/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SIG/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/CAL/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/LOAD/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/state_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/OBS_MODE/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/STATE/SUB_SCAN/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAYDIR_REF/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFDIR_REF/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/REFERENCE_DIR/0.0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/DELAY_DIR/0.0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/field_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/CODE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/NUM_POLY/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/TIME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/FIELD/source_id/
# ...
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/WIND_SPEED_FLAG/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/ns_wx_station_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/ns_wx_station_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/ns_wx_station_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/ns_wx_station_id/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/REL_HUMIDITY/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/REL_HUMIDITY/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/REL_HUMIDITY/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/WEATHER/REL_HUMIDITY/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/POSITION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/POSITION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/POSITION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/POSITION/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/antenna_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/antenna_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/antenna_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/antenna_id/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/OFFSET/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/OFFSET/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/OFFSET/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/OFFSET/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/DISH_DIAMETER/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/DISH_DIAMETER/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/DISH_DIAMETER/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/DISH_DIAMETER/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/TYPE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/STATION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/STATION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/STATION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/STATION/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/MOUNT/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/MOUNT/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/MOUNT/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/MOUNT/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/NAME/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ANTENNA/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/POSITION/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/POSITION/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/POSITION/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/POSITION/0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/STATIONID/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/STATIONID/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/STATIONID/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/STATIONID/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TIME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TIME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TIME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TIME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/TYPE/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/NAME/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/ASDM_STATION/.zmetadata
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TELESCOPE_NAME/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/.zattrs
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE/0.0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zattrs
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/RELEASE_DATE/0
#  extracting: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zgroup
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/OBSERVER/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/observation_id/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/PROJECT/0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/TIME_RANGE/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/LOG/0.0
#    creating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/.zarray
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/.zattrs
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/SCHEDULE_TYPE/0
#   inflating: sis14_twhya_field_5_lsrk_pol_xx.vis.zarr/global/OBSERVATION/.zmetadata
# Archive:  casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr.zip
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/pol/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/pol/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/pol/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/pol/0
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/chan/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/chan/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/chan/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/chan/0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PB_MASK0/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/SUMWT/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/SUMWT/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/SUMWT/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/SUMWT/0.0.0
#  extracting: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/.zgroup
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL_MASK0/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/time/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/time/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/time/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/time/0
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/declination/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/declination/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/declination/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/declination/0.0
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_MASK0/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/MODEL/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/MODEL/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/MODEL/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/MODEL/.zattrs
#  extracting: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/.version
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR_MASK0/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR_MASK0/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR_MASK0/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/IMAGE_PBCOR_MASK0/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PSF/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PSF/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PSF/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/PSF/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/m/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/m/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/m/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/m/0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/.zmetadata
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL/0.0.0.0.0
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/RESIDUAL/.zattrs
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/l/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/l/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/l/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/l/0
#    creating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/right_ascension/
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/right_ascension/.zarray
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/right_ascension/.zattrs
#   inflating: casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr/right_ascension/0.0
# complete

# %% [markdown]
# ## Load Dataset
#
# Two datasets are are needed for this notebook sis14_twhya_field_5_lsrk_pol_xx.vis.zarr and casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr (for more information about the img.zarr format go [here](https://cngi-prototype.readthedocs.io/en/latest/visibilities.html) and for the vis.zarr format go [here](https://cngi-prototype.readthedocs.io/en/latest/images.html)).
#
# The sis14_twhya_field_5_lsrk_pol_xx.vis.zarr dataset is used to create a continuum image. The dataset was created by using the ```mstransform``` command in CASA
#
# ```python
# mstransform('sis14_twhya_calibrated_flagged.ms',
#             outputvis='sis14_twhya_field_5_lsrk_pol_xx.ms',
#             regridms=True, outframe='LSRK', datacolumn='data',
#             correlation='XX',field='5')
# ```
#
# and then convert_ms in cngi.conversion
#
# ```python
# infile = 'sis14_twhya_field_5_lsrk_pol_xx.ms'
# outfile = 'sis14_twhya_field_5_lsrk_pol_xx.vis.zarr'
# chunk_shape=(270, 210, 12, 1)
# convert_ms(infile, outfile=outfile , chunk_shape=chunk_shape)
# ```
#
# The conversion to 'LSRK' is necessary because cngi does not currently have an implementation and tclean does a conversion to 'LSRK' before imaging.
#
# To check the ngcasa imaging results the casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr dataset is used. This dataset was generated by running ```tclean``` in CASA
#
# ```python
# tclean(vis='sis14_twhya_field_5_lsrk_pol_xx.ms',
#        imagename='twhya_standard_gridder_lsrk_mfs_natural',
#        specmode='mfs',
#        deconvolver='hogbom',
#        imsize=[200,400],
#        cell=['0.08arcsec'],
#        weighting='natural',
#        threshold='0mJy',
#        niter=0,stokes='XX')
# ```
#
# and then ```image_ms``` in cngi.conversion
#
# ```python
# infile = 'twhya_standard_gridder_lsrk_mfs_natural.image'
# outfile = 'casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr'
# convert_image(infile=infile,outfile=outfile)
# ```

# %%
import xarray as xr
from cngi.dio import read_vis, read_image

xr.set_options(display_style="html")

mxds = read_vis("sis14_twhya_field_5_lsrk_pol_xx.vis.zarr",chunks={'chan':192})
mxds.xds0
# Out:
# <xarray.Dataset>
# Dimensions:         (baseline: 210, chan: 384, pol: 1, pol_id: 1, spw_id: 1, time: 270, uvw_index: 3)
# Coordinates:
#   * baseline        (baseline) int64 0 1 2 3 4 5 6 ... 204 205 206 207 208 209
#   * chan            (chan) float64 3.725e+11 3.725e+11 ... 3.728e+11 3.728e+11
#     chan_width      (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#     effective_bw    (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#   * pol             (pol) int32 9
#   * pol_id          (pol_id) int32 0
#     resolution      (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#   * spw_id          (spw_id) int32 0
#   * time            (time) datetime64[ns] 2012-11-19T07:56:26.544000626 ... 2...
# Dimensions without coordinates: uvw_index
# Data variables:
#     ANTENNA1        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ANTENNA2        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ARRAY_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     DATA            (time, baseline, chan, pol) complex128 dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     DATA_WEIGHT     (time, baseline, chan, pol) float64 dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     EXPOSURE        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED1           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED2           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FIELD_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FLAG            (time, baseline, chan, pol) bool dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     INTERVAL        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     OBSERVATION_ID  (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     PROCESSOR_ID    (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     SCAN_NUMBER     (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     STATE_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     TIME_CENTROID   (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     UVW             (time, baseline, uvw_index) float64 dask.array<chunksize=(270, 210, 3), meta=np.ndarray>
# Attributes:
#     bbc_no:           2
#     corr_product:     [[0, 0]]
#     data_groups:      [{'0': {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw...
#     freq_group:       0
#     freq_group_name:
#     if_conv_chain:    0
#     meas_freq_ref:    1
#     name:             ALMA_RB_07#BB_2#SW-01#FULL_RES
#     net_sideband:     2
#     num_chan:         384
#     num_corr:         1
#     ref_frequency:    372520022603.63745
#     total_bandwidth:  234366781.0546875

# %% [markdown]
# Note that the chunks parameter in cngi and ngcasa functions specifies the size of a chunk and not the number of chunks (in CASA ```tclean``` chanchunks refers to the number of channel chunks).
#
# The dimensionality of the sis14_twhya_field_5_lsrk_pol_xx.vis.zarr dataset is (time:270,baseline:210,chan:384,pol:1) and a zarr chunk size of (time:270,baseline:210,chan:12,pol:1) was chosen. With the ```cngi.dio.read_vis``` function the dask chunk size was set to (time:270,baseline:210,chan:192,pol:1). For more information concerning chunking go [here](https://cngi-prototype.readthedocs.io/en/latest/development.html).

# %% [markdown]
# ## Flag Data and Create Imaging Weights
# The ```apply_flags``` cngi.vis function sets all values that should be flagged to nan. The ngcasa.imaging code does not internally apply flags but does ignore nan values. [apply_flags documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/cngi/vis/apply_flags/index.html#cngi.vis.apply_flags.apply_flags)
#
# The ```make_imaging_weight``` cngi.imaging function takes the WEIGHT data variables and creates IMAGING_WEIGHT data variable that has dimensions time x baseline x chan x pol (matches the visibility DATA variable). Weighting schemes that are supported include natural, uniform, briggs, briggs_abs. [make_imaging_weight documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_imaging_weight/index.html#ngcasa.imaging.make_imaging_weight.make_imaging_weight)

# %%
from cngi.vis import apply_flags
from ngcasa.imaging import make_imaging_weight

mxds = apply_flags(mxds, 'xds0', flags='FLAG')

imaging_weights_parms = {}
imaging_weights_parms['weighting'] = 'natural'

sel_parms = {}
sel_parms['xds'] = 'xds0'
sel_parms['data_group_in_id'] = 0

grid_parms = {}
grid_parms['chan_mode'] = 'continuum'
grid_parms['image_size'] = [200,400]
grid_parms['cell_size'] = [0.08,0.08]

mxds = make_imaging_weight(mxds, imaging_weights_parms, grid_parms, sel_parms)

mxds.xds0
# Out:
# ######################### Start make_imaging_weights #########################
# Setting data_group_in  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT'}
# Setting default data_group_out  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'IMAGING_WEIGHT'}
# Since weighting is natural input weight will be reused as imaging weight.
# ######################### Created graph for make_imaging_weight #########################
# <xarray.Dataset>
# Dimensions:         (baseline: 210, chan: 384, pol: 1, pol_id: 1, spw_id: 1, time: 270, uvw_index: 3)
# Coordinates:
#   * baseline        (baseline) int64 0 1 2 3 4 5 6 ... 204 205 206 207 208 209
#   * chan            (chan) float64 3.725e+11 3.725e+11 ... 3.728e+11 3.728e+11
#     chan_width      (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#     effective_bw    (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#   * pol             (pol) int32 9
#   * pol_id          (pol_id) int32 0
#     resolution      (chan) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#   * spw_id          (spw_id) int32 0
#   * time            (time) datetime64[ns] 2012-11-19T07:56:26.544000626 ... 2...
# Dimensions without coordinates: uvw_index
# Data variables:
#     ANTENNA1        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ANTENNA2        (baseline) int32 dask.array<chunksize=(210,), meta=np.ndarray>
#     ARRAY_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     DATA            (time, baseline, chan, pol) complex128 dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     DATA_WEIGHT     (time, baseline, chan, pol) float64 dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     EXPOSURE        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED1           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FEED2           (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FIELD_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     FLAG            (time, baseline, chan, pol) bool dask.array<chunksize=(270, 210, 192, 1), meta=np.ndarray>
#     INTERVAL        (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     OBSERVATION_ID  (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     PROCESSOR_ID    (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     SCAN_NUMBER     (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     STATE_ID        (time, baseline) int32 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     TIME_CENTROID   (time, baseline) float64 dask.array<chunksize=(270, 210), meta=np.ndarray>
#     UVW             (time, baseline, uvw_index) float64 dask.array<chunksize=(270, 210, 3), meta=np.ndarray>
# Attributes:
#     bbc_no:           2
#     corr_product:     [[0, 0]]
#     data_groups:      [{'0': {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw...
#     freq_group:       0
#     freq_group_name:
#     if_conv_chain:    0
#     meas_freq_ref:    1
#     name:             ALMA_RB_07#BB_2#SW-01#FULL_RES
#     net_sideband:     2
#     num_chan:         384
#     num_corr:         1
#     ref_frequency:    372520022603.63745
#     total_bandwidth:  234366781.0546875

# %% [markdown]
# ## Create Dirty Continuum Image and Primary Beam
# The ```make_image``` cngi.imaging function grids the data (using the prolate spheroidal function as an anti-aliasing filter), fast Fourier transform the gridded data to an image and normalizes the image. The ```make_pb``` function currently supports rotationally symmetric airy disk primary beams. The ```write_zarr``` function is now used to trigger a compute (which includes applying the flags, creating the imaging weights and making the image).
#
# [make_pb documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_mosaic_pb/index.html#ngcasa.imaging.make_mosaic_pb.make_mosaic_pb)
#
# [make_image documentation](https://cngi-prototype.readthedocs.io/en/latest/_api/autoapi/ngcasa/imaging/make_image/index.html#ngcasa.imaging.make_image.make_imagel)

# %%
from ngcasa.imaging import make_image
from ngcasa.imaging import make_pb
from cngi.dio import write_image
import dask

grid_parms = {}
grid_parms['chan_mode'] = 'continuum'
grid_parms['image_size'] = [200,400]
grid_parms['cell_size'] = [0.08,0.08]
grid_parms['phase_center'] = mxds.FIELD.PHASE_DIR[0,0,:].data.compute()

vis_sel_parms = {}
vis_sel_parms['xds'] = 'xds0'
vis_sel_parms['data_group_in_id'] = 0

img_sel_parms = {}
img_sel_parms['data_group_out_id'] = 0

img_xds = xr.Dataset() #empty dataset

img_xds = make_image(mxds, img_xds, grid_parms, vis_sel_parms, img_sel_parms)


make_pb_parms = {}
make_pb_parms['function'] = 'alma_airy'
make_pb_parms['list_dish_diameters'] = [10.7]
make_pb_parms['list_blockage_diameters'] = [0.75]

sel_parms = {}
sel_parms['img_description_in_indx'] = 0


img_xds = make_pb(img_xds,make_pb_parms, grid_parms, sel_parms)


img_xds = write_image(img_xds, 'twhya_standard_gridder_lsrk_mfs_natural.img.zarr')
# Out:
# ######################### Start make_image #########################
# Setting default image_center  to  [100 200]
# Setting default fft_padding  to  1.2
# Setting data_group_in  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '0', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'DATA_WEIGHT'}
# Setting default data_group_out  to  {'data': 'DATA', 'flag': 'FLAG', 'id': '1', 'uvw': 'UVW', 'weight': 'DATA_WEIGHT', 'imaging_weight': 'DATA_WEIGHT'}
# Setting default data_group_in  to  {'id': '0'}
# Setting default data_group_out [' sum_weight ']  to  SUM_WEIGHT
# Setting default data_group_out [' image ']  to  IMAGE
# ######################### Created graph for make_image #########################
# ######################### Start make_pb #########################
# Setting default data_group_in  to  {'id': '0', 'sum_weight': 'SUM_WEIGHT', 'image': 'IMAGE'}
# Setting default data_group_out  to  {'id': '0', 'sum_weight': 'SUM_WEIGHT', 'image': 'IMAGE', 'pb': 'PB'}
# Setting default image_center  to  [100 200]
# Setting default fft_padding  to  1.2
# ######################### Created graph for make_pb #########################
# Time to store and execute graph  write_zarr 3.48569393157959

# %%
casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr")
casa_img_xds
# Out:
# <xarray.Dataset>
# Dimensions:            (chan: 1, l: 200, m: 400, pol: 1, time: 1)
# Coordinates:
#   * chan               (chan) float64 3.726e+11
#     declination        (l, m) float64 dask.array<chunksize=(200, 400), meta=np.ndarray>
#   * l                  (l) float64 3.879e-05 3.84e-05 ... -3.801e-05 -3.84e-05
#   * m                  (m) float64 -7.757e-05 -7.718e-05 ... 7.679e-05 7.718e-05
#   * pol                (pol) float64 9.0
#     right_ascension    (l, m) float64 dask.array<chunksize=(200, 400), meta=np.ndarray>
#   * time               (time) datetime64[ns] 2012-11-19T07:56:26.544000626
# Data variables:
#     IMAGE              (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_MASK0        (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_PBCOR        (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     IMAGE_PBCOR_MASK0  (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     MODEL              (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PB                 (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PB_MASK0           (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     PSF                (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     RESIDUAL           (l, m, time, chan, pol) float64 dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     RESIDUAL_MASK0     (l, m, time, chan, pol) bool dask.array<chunksize=(200, 400, 1, 1, 1), meta=np.ndarray>
#     SUMWT              (time, chan, pol) float64 dask.array<chunksize=(1, 1, 1), meta=np.ndarray>
# Attributes:
#     axisnames:            ['Right Ascension', 'Declination', 'Time', 'Frequen...
#     axisunits:            ['rad', 'rad', 'datetime64[ns]', 'Hz', '']
#     commonbeam:           [0.6637904644012451, 0.5050938129425049, -65.900085...
#     commonbeam_units:     ['arcsec', 'arcsec', 'deg']
#     date_observation:     2012/11/19/07
#     direction_reference:  j2000
#     imagetype:            Intensity
#     incr:                 [-3.878509448876288e-07, 3.878509448876288e-07, 1.0...
#     object_name:          tw hya
#     observer:             cqi
#     pointing_center:      11
#     rest_frequency:       3.72637e+11 hz
#     restoring_beam:       0.66379 arcsec, 0.505094 arcsec, -65.9001 deg
#     restoringbeam:        [0.6637904644012451, 0.5050938129425049, -65.900085...
#     spectral__reference:  lsrk
#     telescope:            alma
#     telescope_position:   [2.22514e+06m, -5.44031e+06m, -2.48103e+06m] (itrf)
#     unit:                 Jy/beam
#     velocity__type:       radio

# %% [markdown]
# ## Plot and Compare With CASA

# %%
import matplotlib.pylab as plt
import numpy as np

img_xds = read_image("twhya_standard_gridder_lsrk_mfs_natural.img.zarr")
casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr")
plt.close('all')

#### Compare dirty images ####
dirty_image = img_xds['IMAGE'].isel(chan=0,time=0,pol=0) #Image created by ngCASA
casa_dirty_image = casa_img_xds['RESIDUAL'].isel(chan=0,time=0,pol=0) #Image created by CASA

#Plotting Images
minmin = np.min([np.min(casa_dirty_image.data), np.min(dirty_image.data)])
maxmax = np.max([np.max(casa_dirty_image.data), np.max(dirty_image.data)])
extent = extent=(np.min(casa_dirty_image.m),np.max(casa_dirty_image.m),np.min(casa_dirty_image.l),np.max(casa_dirty_image.l))

fig0, ax0 = plt.subplots(1, 2, sharey=True,figsize=(10, 5))
im0 = ax0[0].imshow(casa_dirty_image,extent=extent)
im1 = ax0[1].imshow(dirty_image,extent=extent)
ax0[0].title.set_text('CASA Dirty Image')
ax0[1].title.set_text('ngCASA Dirty Image')
ax0[0].set_xlabel('m')
ax0[1].set_xlabel('m')
ax0[0].set_ylabel('l')
ax0[1].set_ylabel('l')
fig0.colorbar(im0, ax=ax0[0], fraction=0.046, pad=0.04)
fig0.colorbar(im1, ax=ax0[1], fraction=0.046, pad=0.04)
plt.show()

dif_image = casa_dirty_image - dirty_image
plt.figure()
plt.imshow(dif_image,extent=extent)
plt.title('Difference Dirty Image')
plt.xlabel('m')
plt.ylabel('l')
plt.colorbar(fraction=0.046, pad=0.04)
plt.show()

dirty_image = dirty_image / np.max(np.abs(dirty_image))
casa_dirty_image = casa_dirty_image / np.max(np.abs(casa_dirty_image))

# Calculate max error
max_error_dirty_image = np.max(np.abs(dirty_image - casa_dirty_image)).values
print('Max Error',max_error_dirty_image)

# Calculate root mean square error
rms_error_dirty_image = np.linalg.norm(dirty_image - casa_dirty_image, 'fro')
print('RMS Error',rms_error_dirty_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Max Error 2.2810074962187343e-07
# RMS Error 1.664748669073348e-05

# %% [markdown]
# The reason for the small difference between ngCASA and CASA is due to ngCASA using a different implementation of the Fast Fourier Transform.

# %%
import matplotlib.pylab as plt
import numpy as np
import xarray as xr
import dask.array as da
import dask
from cngi.dio import read_image

img_xds = read_image("twhya_standard_gridder_lsrk_mfs_natural.img.zarr").isel(chan=0, pol=0, time=0, dish_type=0)
casa_img_xds = read_image("casa_twhya_standard_gridder_lsrk_mfs_natural.img.zarr").isel(chan=0, time=0, pol=0)
plt.close('all')


#### Primary Beam Corrected Images ####
pb_limit = 0.2

primary_beam = img_xds.PB.isel(l=100).where(img_xds.PB.isel(l=100) > pb_limit,other=0.0)
dirty_image_pb_cor = img_xds.IMAGE/img_xds.PB
dirty_image_pb_cor = dirty_image_pb_cor.where(img_xds.PB > pb_limit,other=np.nan)

#print(casa_img_xds)
casa_primary_beam = casa_img_xds['PB'].isel(l=100).data #Primary beam created by CASA
casa_dirty_image_pb_cor = (casa_img_xds['IMAGE_PBCOR']).where(casa_img_xds['PB'] > pb_limit,other=np.nan) #Image created by CASA

#Plot Primary Beams
fig0, ax0, = plt.subplots(1, 2, sharey=True,figsize=(10, 5))
im0 = ax0[0].plot(casa_dirty_image.m,casa_primary_beam)
im1 = ax0[1].plot(casa_dirty_image.m,primary_beam)
ax0[0].title.set_text('CASA Primary Beam Cross Section')
ax0[1].title.set_text('ngCASA Primary Beam Cross Section')
ax0[0].set_xlabel('m')
ax0[1].set_xlabel('m')
ax0[0].set_ylabel('Amplitude')
ax0[1].set_ylabel('Amplitude')
plt.show()

plt.figure()
plt.plot(casa_dirty_image.m,casa_primary_beam-primary_beam)
plt.title('Difference Primary Beam')
plt.xlabel('m')
plt.ylabel('Amplitude')
plt.show()


extent=(np.min(casa_dirty_image.m),np.max(casa_dirty_image.m),np.min(casa_dirty_image.l),np.max(casa_dirty_image.l))

#Plotting Images
fig0, ax0 = plt.subplots(1, 2, sharey=True,figsize=(10, 5))
im0 = ax0[0].imshow(casa_dirty_image_pb_cor,extent=extent)
im1 = ax0[1].imshow(dirty_image_pb_cor,extent=extent)
ax0[0].title.set_text('CASA PB Corrected Dirty Image')
ax0[1].title.set_text('ngCASA PB Corrected Dirty Image')
ax0[0].set_xlabel('m')
ax0[1].set_xlabel('m')
ax0[0].set_ylabel('l')
ax0[1].set_ylabel('l')
fig0.colorbar(im0, ax=ax0[0], fraction=0.046, pad=0.04)
fig0.colorbar(im1, ax=ax0[1], fraction=0.046, pad=0.04)
plt.show()
 
plt.figure()
plt.imshow(casa_dirty_image_pb_cor - dirty_image_pb_cor,extent=extent)
plt.title('Difference Dirty Image')
plt.xlabel('m')
plt.ylabel('l')
plt.colorbar(fraction=0.046, pad=0.04)
plt.show()

dirty_image_pb_cor = dirty_image_pb_cor / np.nanmax(np.abs(dirty_image_pb_cor))
casa_dirty_image_pb_cor = casa_dirty_image_pb_cor / np.nanmax(np.abs(casa_dirty_image_pb_cor))
norm_diff_image_pb_cor = dirty_image_pb_cor - casa_dirty_image_pb_cor

# Calculate max error
max_error_dirty_image = np.nanmax(np.abs(norm_diff_image_pb_cor))
print('Max Normalized Error',max_error_dirty_image)

# Calculate root mean square error
rms_error_dirty_image = np.sqrt(np.nansum(np.square(norm_diff_image_pb_cor)))
print('RMS Normalized Error',rms_error_dirty_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Max Normalized Error 0.0005570343301252167
# RMS Normalized Error 0.011389306569008918

# %% [markdown]
# The difference in primary beam is due to CASA using a sampled 1D function while ngCASA calculates the PB for each pixel. If it is found that PB creation becomes a bottleneck for ngCASA the implementation will be changed to match CASA.
